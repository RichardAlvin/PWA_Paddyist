# %%
import os
import time
import cv2
import glob
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import io
import numpy as np
from PIL import Image
import imageio.v2 as imageio
import random
from numpy import expand_dims
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

# %%
#data awal setelah dipisah secara manual. Data yang lebih dari 1000, telah dipisah secara manual
beginning_path = 'aug_oversampling_v2_dataset/separate_to_1000_image'
print('Dataset Awal Setelah Dipisah Manual')
for filepath in glob.glob(beginning_path + '/*/'):
    files = glob.glob(filepath + '*')
    print(f"{len(files)} \t {Path(filepath).name}")
# Out:
# Dataset Awal Setelah Dipisah Manual
# 379 	 bacterial_leaf_blight
# 280 	 bacterial_leaf_streak
# 237 	 bacterial_panicle_blight
# 1000 	 blast
# 865 	 brown_spot
# 1000 	 dead_heart
# 520 	 downy_mildew
# 1000 	 hispa
# 1000 	 normal
# 1000 	 tungro

# %%
#Augment class image yang kurang dari 1000 gambar
#nanti bikin folder dengan nama balanced_oversampling

def blur(img):
    return (cv2.blur(img,(random.randint(1, 3),random.randint(1, 3))))

datagen = ImageDataGenerator(
    brightness_range=[0.3,1],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    preprocessing_function=blur,
    zoom_range=[0.5,1.0]
)

# %%
img = load_img('basic_dataset/train/bacterial_leaf_blight/100023.jpg')
data = img_to_array(img)
samples = expand_dims(data, 0)
it = datagen.flow(samples, batch_size=1)
for i in range(3):
    pyplot.subplot(230 + 1 + i)
    batch = it.next()
    image = batch[0].astype('uint8')
    pyplot.imshow(image)
pyplot.show()

# %%
#Bacterial_Leaf_Blight - 379
#1000 - 379 = 621
#207 Gambar diaugment dengan iterasi 3 kali ==> 621
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_leaf_blight/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/bacterial_leaf_blight/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_leaf_blight/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 3:
            break
    
    
    i += 1
    if i > 210:
        break

# %%
#Bacterial_Leaf_Streak - 280
#1000 - 280 = 720
#180 Gambar diaugment dengan iterasi 4 kali ==> 720
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_leaf_streak/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/bacterial_leaf_streak/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_leaf_streak/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 4:
            break
    
    
    i += 1
    if i > 185:
        break

# %%
#Bacterial_Panicle_Blight - 237
#1000 - 237 = 763
#191 Gambar diaugment dengan iterasi 4 kali ==> 763
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_panicle_blight/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/bacterial_panicle_blight/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/bacterial_panicle_blight/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 4:
            break
    
    
    i += 1
    if i > 197:
        break

# %%
#Brown_Spot - 865
#1000 - 865 = 135
#45 Gambar diaugment dengan iterasi 3 kali ==> 135
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/brown_spot/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/brown_spot/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/brown_spot/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 3:
            break
    
    
    i += 1
    if i > 47:
        break

# %%
#Downy_Mildew - 520
#1000 - 520 = 480
#120 Gambar diaugment dengan iterasi 4 kali ==> 480
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/downy_mildew/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/downy_mildew/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/downy_mildew/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 4:
            break
    
    
    i += 1
    if i > 128:
        break

# %%
#Tungro - 988
#1000 - 988 = 12
#4 Gambar diaugment dengan iterasi 3 kali ==> 12
folder_dir = "aug_oversampling_v2_dataset/separate_to_1000_image/tungro/"
save_here = "aug_oversampling_v2_dataset/balanced_oversampling/tungro/"
i = 1
for image in os.listdir(folder_dir):
    image_path = 'aug_oversampling_v2_dataset/separate_to_1000_image/tungro/'+image
    image = np.expand_dims(imageio.imread(image_path), 0)
    datagen.fit(image)
    
    j=1
    for x in datagen.flow(image,
                         batch_size=1,
                         save_to_dir=save_here,
                         save_prefix='aug',
                         save_format='jpg'):
        j += 1
        if j > 3:
            break
    
    
    i += 1
    if i > 5:
        break

# %%
#data akhir setelah diaugmentasi
beginning_path = 'aug_oversampling_v2_dataset/balanced_oversampling'
print('Dataset Akhir Setelah Diaugmentasi')
for filepath in glob.glob(beginning_path + '/*/'):
    files = glob.glob(filepath + '*')
    print(f"{len(files)} \t {Path(filepath).name}")
# Out:
# Dataset Akhir Setelah Diaugmentasi
# 990 	 bacterial_leaf_blight
# 988 	 bacterial_leaf_streak
# 997 	 bacterial_panicle_blight
# 1000 	 blast
# 1000 	 brown_spot
# 1000 	 dead_heart
# 1000 	 downy_mildew
# 1000 	 hispa
# 1000 	 normal
# 1000 	 tungro
